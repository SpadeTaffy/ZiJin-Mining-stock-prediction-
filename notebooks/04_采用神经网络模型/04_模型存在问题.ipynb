# %% [markdown]
# 经过之前的探究,铜,金的价格有上升趋势,在数据集中有没有见过的新情况,导致外推可能变差.

# %% [markdown]
# 我们保留7-16-32-1的模型作为基础,不要再继续让模型复杂化.暂时认为不是训练的问题,而是信息缺失的问题.

# %% [markdown]
# 在我们之前的线性模型设计中,由于特征是我自己设计的,其中一些隐秘的关系可能并没有被有效地利用.比如MACD,RSI等指标,是否能通过让模型自己找到里面的关系,进而提升预测的准确率呢?

# %% [markdown]
#  之前计算得到的紫金矿业铜,金占比;季度扣非净利润,也可以加入进去,用于对比;产量同步变化,能否也用于预测?

# %% [markdown]
# 交易量的关系,是否也能代入进去,让模型自行寻找关系?

# %% [markdown]
# 之前加入波动率,对模型预测也有一定影响.将其也保留下来.

# %% [markdown]
# 金价,铜价的波动率,金铜价格的macd,RSI,相对均线的偏离量,是否能作为额外的信息.
